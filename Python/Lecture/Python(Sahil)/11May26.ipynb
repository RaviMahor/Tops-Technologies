# %%
print("hello")
# Out:
# hello

# %%
# 12343
# 12343
# 12343

# %%
name = "rahul"
age = 23
marks = 90.5
is_present = True   

print(name)
print(age)
print(marks)
print(is_present)
# Out:
# rahul
# 23
# 90.5
# True

# %%
print(type(name))
print(type(age))
print(type(marks))
print(type(is_present))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
