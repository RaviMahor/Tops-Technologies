# %%
numbers = (10, 20, 20, 20, 30, 40, 50)

# count(value)
# Returns number of times value appears

print(numbers.count(20))  # Output: 3
""" 
how to use count() method in tuple? 
The count() method in a tuple is used to count the number of occurrences of a specific value within the tuple. It takes one argument, which is the value you want to count. The method returns an integer representing the number of times the specified value appears in the tuple.
Here's how you can use the count() method in a tuple:
```python
"""
# Out:
# 3
# " how to use count() method in tuple? \nThe count() method in a tuple is used to count the number of occurrences of a specific value within the tuple. It takes one argument, which is the value you want to count. The method returns an integer representing the number of times the specified value appears in the tuple.\nHere's how you can use the count() method in a tuple:\n```python\n"

# %%
# index(value)
# Returns first index position of value
print(numbers.index(30))  # Output: 4
""" 
how to use index() method in tuple?
The index() method in a tuple is used to find the first index position of a specified value within the tuple. It takes one argument, which is the value you want to find. The method returns an integer representing the index of the first occurrence of the specified value in the tuple. If the value is not found, it raises a ValueError.
"""
# Out:
# 4
# ' how to use index() method in tuple?\nThe index() method in a tuple is used to find the first index position of a specified value within the tuple. It takes one argument, which is the value you want to find. The method returns an integer representing the index of the first occurrence of the specified value in the tuple. If the value is not found, it raises a ValueError.\n'
