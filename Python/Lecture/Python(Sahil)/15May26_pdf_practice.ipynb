# %%
age = int("19")
print(age)
print(type(age))
# Out:
# 19
# <class 'int'>

# %%
m1 = "70.5"
m2 = "80.0"
m3 = "90.5"

f1 = float(m1)
f2 = float(m2)
f3 = float(m3)

age = int(input("age :"))
print(age + 5)
# Out:
# 6
# 80.33333333333333

# %%
Average = (f1+f2+f3)/3
print("aveage marks:",Average)
# Out:
# aveage marks: 80.33333333333333

# %%
std_code = (input("enter std :"))
Phone_number = (input("enter phone number :"))
print(std_code +" "+ Phone_number)
# Out:
# +91 1111111111

# %%
message1 = input("enter message :")
print(message1)
# Out:
# 1

# %%
brand = "x 20 pro max"
print(brand.capitalize())
# Out:
# X 20 pro max

# %%
product_name = "apple phone"
product_name.replace("phone", "mobile")
print(product_name.capitalize())
# Out:
# Apple phone

# %%
# 1. print "welcome to python" on screen.
print("welcome to python")
# Out:
# welcome to python

# %%
# 2. create a variable called city and store your city name. print its datatype.
city = "New York"
print(city)
print(type(city))
# Out:
# New York
# <class 'str'>

# %%
# 3. store your age in a variable and check its type.
age = 25
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
# 4. take user input for marks and print its datatype. why is it string?
marks = input("enter marks : ")
print(marks)
print(type(marks))
"""
it is string because input function always returns a string value.
even if we enter a number, it will be treated as a string.
to convert it to a number, we can use int() or float() function. 
for example, if we want to convert marks to an integer, we can use int(marks).
if we want to convert marks to a float, we can use float(marks).
"""
# Out:
# 33
# <class 'str'>
# '\nit is string because input function always returns a string value.\neven if we enter a number, it will be treated as a string.\nto convert it to a number, we can use int() or float() function. \nfor example, if we want to convert marks to an integer, we can use int(marks).\nif we want to convert marks to a float, we can use float(marks).\n'

# %%
# 5. convert the marks input into float and print new datatype.
marks = input("enter marks : ")
marks_float = float(marks)
print(marks_float)
print(type(marks_float))
# Out:
# 1111.0
# <class 'float'>

# %%
"""
6. what is the difference between :
print(10 + 5)
print("10" + "5")
"""
print(10 + 5) # this will print 15 because it is adding two integers.
print("10" + "5") # this will print "105" because it is concatenating two strings. it is not adding the numbers, it is joining the strings together.
# Out:
# 15
# 105

# %%
"""
7. create a string  "programming" and print:
a) first charactor
b) last charactor
"""
string = "programming"
print(string[0]) # this will print 'p' because it is the first character of the string.
print(string[-1]) # this will print 'g' because it is the last character of the string.
# Out:
# p
# g

# %%
# 8. from "pythonprogramming", extract only "python" using slicing.
string = "pythonprogramming"
substring = string[0:6] # this will extract the substring from index 0 to index 5 (6 is not included).
print(substring) # this will print "python".
# Out:
# python

# %%
# 9. convert "data science" into upppwecase.
string = "data science"
uppercase_string = string.upper() # this will convert the string to uppercase.
print(uppercase_string) # this will print "DATA SCIENCE".
# Out:
# DATA SCIENCE

# %%
# 10. convert "MACHINE LEARNING" into lowercase.    
string = "MACHINE LEARNING"
lowercase_string = string.lower() # this will convert the string to lowercase.
print(lowercase_string) # this will print "machine learning".
# Out:
# machine learning

# %%
# 11. Replace "phone" with "mobile" in "apple phone".
string = "apple phone"
new_string = string.replace("phone", "mobile") # this will replace "phone" with "mobile" in the string.
print(new_string) # this will print "apple mobile".
# Out:
# apple mobile

# %%
""""
 12. Split this sentence into words:
 "Python is very powerful"
"""
sentence = "Python is very powerful"
splitsentence = sentence.split()

print(splitsentence)
# Out:
# ['Python', 'is', 'very', 'powerful']

# %%
"""
13. Use f-string to print:
My name is Rahul and age is 21
"""
Name = "Rahul"
age = 21
print(f"My name is {Name} and age is {age}")
# Out:
# My name is Rahul and age is 21

# %%
"""
14. Clean this product name:
"samsung-Mobile"
Final output should be "Samsung Mobile"
"""
product_name = "samsung-Mobile"
cleaned_product_name = product_name.replace("samsung", "Samsung").replace("Mobile", "Mobile").replace("-", " ") # this will replace "samsung" with "Samsung", "Mobile" with "Mobile" and "-" with " " in the string.
print(cleaned_product_name) # this will print "Samsung Mobile".
# Out:
# Samsung Mobile

# %%
# 15. Write one line explaining why data types are important.
"""
Data types are important because they help us to store and manipulate data in a way that is easy to understand and use.
"""

# %%
# 1. Print "Learning Python is fun!" on screen.
print("Learning Python is fun!")
# Out:
# Learning Python is fun!

# %%
"""
2. Create a variable called country and store "India".
Print its datatype using type().
"""
country = "India"
print(type(country))
# Out:
# <class 'str'>

# %%
# 3. Store your birth year in a variable and print its datatype.
birth_year = 1990
print(type(birth_year))
# Out:
# <class 'int'>

# %%
""" 
4. Take user input for salary and print its datatype. 
Why does input() always return a string?
"""
salary = input("Enter your salary: ")
print(type(salary))
"""
Input() always return a string because it is used to take input from the user.
"""
# Out:
# <class 'str'>
# '\nInput() always return a string because it is used to take input from the user.\n'

# %%
# 5. Convert the salary input into a float and print new datatype.
salary = input("Enter your salary: ")
salary_float = float(salary)
print(salary_float)
print(type(salary_float))
# Out:
# 15000.0
# <class 'float'>

# %%
"""
6. Observe and explain:
print(20 +10)
print ("20" + "10")
"""
print(20 + 10) # This will print 30 because it is adding two integers.
print("20" + "10") # This will print "2010" because it is concatenating two strings. It is not adding the numbers, it is joining the strings together.
# Out:
# 30
# 2010

# %%
""" 
7. Create a string "DataAnalytics" and print:
a) First character
b) Last character
"""
data_analytics = "DataAnalytics"
print(data_analytics[0])  # This will print the first character
print(data_analytics[-1])  # This will print the last character
# Out:
# D
# s

# %%
# 8. From "MachineLearning", extract only "Machine" using slicing.
string = "MachineLearning"
substring = string[0:7] # this will extract the substring from index 0 to index 6 (7 is not included).
print(substring) # this will print "Machine".
# Out:
# Machine

# %%
# 9. Convert "artificial intelligence" into uppercase.
string = "artificial intelligence"
uppercase_string = string.upper() # this will convert the string to uppercase.
print(uppercase_string) # this will print "ARTIFICIAL INTELLIGENCE".
# Out:
# ARTIFICIAL INTELLIGENCE

# %%
# 10. Convert "BIG DATA" into lowercase.
string = "BIG DATA"
lowercase_string = string.lower() # this will convert the string to lowercase.
print(lowercase_string) # this will print "big data".
# Out:
# big data

# %%
"""
11. Replace "Old" with "New" in:
"Old Laptop"
"""
string = "Old Laptop"
new_string = string.replace("Old", "New") # this will replace "Old" with "New" in the string.
print(new_string) # this will print "New Laptop".
# Out:
# New Laptop

# %%
"""
12. Split this sentence into words:
"Python makes coding easy"
"""
sentence = "Python makes coding easy"
splitsentence = sentence.split()
print(splitsentence)
# Out:
# ['Python', 'makes', 'coding', 'easy']

# %%
"""
13. Use f-string to print:
My city is Mumbai and my age is 22
"""
city = "Mumbai"
age = 22
print(f"My city is {city} and my age is {age}")
# Out:
# My city is Mumbai and my age is 22

# %%
"""
14. Real life cleaning:
Raw product name:
" HP-Laptop "
Perform these steps:
- remove spaces
- convert to lowercase
- replace "-" with space
Final output should be:
hp laptop
"""
raw_product_name = " HP-Laptop "
cleaned_product_name = raw_product_name.strip().lower().replace("-", " ") # this will remove spaces, convert to lowercase and replace "-" with space in the string.
print(cleaned_product_name) # this will print "hp laptop".
# Out:
# hp laptop

# %%
""" 
15. Hardest Question:
Take input for product price as string,
convert it to float,
add 18% GST,
and print final price.
Example:
Input: "1000"
Output: 1180.0
Write one line explaining WHY type casting is needed.
"""
price_str = input("Enter product price: ")
price_float = float(price_str)
final_price = price_float + (price_float * 0.18) # this will add 18% GST to the price.
print(final_price) # this will print the final price with GST.
"""
Type casting is needed to convert the input string into a numeric type (like float) so that we can perform mathematical operations on it, such as adding GST.
"""
# Out:
# 1180.0
# '\nType casting is needed to convert the input string into a numeric type (like float) so that we can perform mathematical operations on it, such as adding GST.\n'
