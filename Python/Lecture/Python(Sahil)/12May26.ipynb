# %%
print(10+5) # number addition
print("10"+"5") # string concatenation
# Out:
# 15
# 105

# %%
a = input("Enter first name: ")
b = input("Enter last name: ")
print(a + " " + b)
# Out:
# Ravi Mahor

# %%
A = input("Enter Code: ")
B = input("Enter Phone Number: ")

C = A + B
D = int(C)
print("Code with phone number: ", D)
print(type(D))
# Out:
# Code with phone number:  111111111111
# <class 'int'>

# %%
Name = "0"
Name = bool(Name)
print(Name)
print(type(Name))
# Out:
# True
# <class 'bool'>
