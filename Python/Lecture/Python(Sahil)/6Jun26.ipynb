# %%
def greet():
    print("Welcom to Python")

# Calling the function
greet()
# Out:
# Welcom to Python

# %%
from re import A
a = int(input(" Enter value:"))
b = int(input(" Enter value:"))
def Add(a,b): # a,b ye perameter hea
    A = a + b
    print(A)

# Add(1,1) # (1,1) ye argument hea
Add(a,b)
# Out:
# 2
