# %%
def greet():
    print("Hello Student")

greet()
greet()
greet()
greet()

# %%
def greet():
    print("Hello Student")

greet()
greet()
greet()
greet()
# Out:
# Hello Student
# Hello Student
# Hello Student
# Hello Student

# %%
def greet(name):
    print("Hello", name)

greet("Rahul")
greet("Sahil")
greet("Ajay")
greet("Rahu")
