# %%
numbers = [1, 2, 3, 4, 5]
print(numbers)
#modify element
numbers[0] = 10
#numbers[3] = 40
print(numbers)
# Out:
# [1, 2, 3, 4, 5]
# [10, 2, 3, 4, 5]

# %%
#add element
numbers.append(6)
print(numbers)
# Out:
# [10, 2, 3, 4, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]

# %%
#remove element
numbers.remove(6)
print(numbers)
# Out:
# [10, 3, 4, 5, 6, 6]

# %%
marks = [90, 80, 70, 60, 50]
average = sum(marks) / len(marks)
sum_marks = sum(marks)
percentage = (sum_marks / 500) * 100
print("Total marks:", sum_marks)
print("Average marks:", average)
b = "%"
c = "Percentage: " + str(percentage) + "%" # string concatenation
print(c)
print("Percentage:", percentage, "%")
# Out:
# Total marks: 350
# Average marks: 70.0
# Percentage: 70.0%
# Percentage: 70.0 %
