# %%
student_name = input("enter your name: ")
print(student_name.upper())
print(student_name.lower())
print(student_name.title())
print(student_name.capitalize())
print(student_name[0:3])
# Out:
# RAVI
# ravi
# Ravi
# Ravi
# rav

# %%
print("Enter your address in this sequance")
print("1. house/flat")
print("2. street name")
print("3. city")
print("4. state")
print("5. country")
print("6. pin code")
User_Info1 = input("Enter your 1. house/flat: ")
User_Info2 = input("Enter your 2. street name: ")
User_Info3 = input("Enter your 3. city: ")
User_Info4 = input("Enter your 4. state: ")
User_Info5 = input("Enter your 5. country: ")
User_Info6 = input("Enter your 6. pin code: ")
print(f"your full address is:{User_Info1}")
print(f"{User_Info2},")
print(f"{User_Info3},")
print(f"{User_Info4},")
print(f"{User_Info5},")
print(f"{User_Info6}.")
# Out:
# Enter your address in this sequance
# 1. house/flat
# 2. street name
# 3. city
# 4. state
# 5. country
# 6. pin code
# your full address is:11
# dalal,
# gift,
# gujarat,
# 39030303,
# jdjd,
