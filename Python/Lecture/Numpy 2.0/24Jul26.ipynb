# %%
import numpy as np 
arr = np.array([9.234, 6.567, 3.891])

print(np.round(arr,1))
print(np.floor(arr))
print(np.ceil(arr))
# Out:
# [9.2 6.6 3.9]
# [9. 6. 3.]
# [10.  7.  4.]

# %%
arr
# Out:
# array([9.234, 6.567, 3.891])

# %%
np.median(arr)
# Out:
# np.float64(6.567)

# %%
np.prod(arr)
# Out:
# np.float64(235.948987098)

# %%
np.cumsum(arr)
# Out:
# array([ 9.234, 15.801, 19.692])

# %%
np.percentile(arr,90)
# Out:
# np.float64(8.7006)

# %%
x = np.array([10,20,20,30,2020,2020,202,2020])
x[::-1]
# Out:
# array([2020,  202, 2020, 2020,   30,   20,   20,   10])

# %%
x[:5:]
# Out:
# array([  10,   20,   20,   30, 2020])

# %%
x[2:5:]
# Out:
# array([  20,   30, 2020])

# %%
x[-5::2]
# Out:
# array([  30, 2020, 2020])

# %%
y = np.random.randint(10,100,12,).reshape(3,4)
print(y)
# Out:
# [[63 14 89 83]
#  [53 41 42 44]
#  [26 52 57 49]]

# %%
y[::]
# Out:
# array([[63, 14, 89, 83],
#        [53, 41, 42, 44],
#        [26, 52, 57, 49]])

# %%
y[::2,1::2]
# Out:
# array([[14, 83],
#        [52, 49]])

# %%
y[1::,::3]
# Out:
# array([[53, 44],
#        [26, 49]])

# %%
y[-1::]
# Out:
# array([[26, 52, 57, 49]])

# %%
y = np.random.randint(10,100,27).reshape(3,3,3)
print(y)
# Out:
# [[[40 58 19]
#   [30 35 83]
#   [81 14 63]]
#
#  [[53 24 79]
#   [96 52 87]
#   [95 65 43]]
#
#  [[83 84 95]
#   [10 13 42]
#   [34 82 76]]]

# %%
y[layer:row:column]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 y[layer:row:column]
#
# NameError: name 'layer' is not defined

# %%
"""https://colab.research.google.com/drive/1txdHwzQy4vsJ_n6h7lwluRUu3hmFfTFV?usp=sharing#scrollTo=_wapW622Vf1t"""

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])

print(np.concatenate((a,b)))
print(np.hstack((a,b)))
print(np.vstack((a,b)))
# Out:
# [1 2 3 4 5 6]
# [1 2 3 4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %%
arr = np.arange(9)
print(np.split(arr,3))
# Out:
# [array([0, 1, 2]), array([3, 4, 5]), array([6, 7, 8])]

# %%
arr = np.array([1,2,3,4])
print(np.insert(arr,2,10))
print(np.append(arr,10))
print(np.delete(arr,2))
# Out:
# [ 1  2 10  3  4]
# [ 1  2  3  4 10]
# [1 2 4]

# %%
arr = np.array([1,2,2,3,3,3,4])
print(np.unique(arr))
# Out:
# [1 2 3 4]

# %%
arr = np.array([3,1,4,1,5,9])
print(np.sort(arr))
print(np.argsort(arr))
# Out:
# [1 1 3 4 5 9]
# [1 3 0 2 4 5]

# %%
arr = np.array([0,1,2,0])
print(np.nonzero(arr))
# Out:
# (array([1, 2]),)

# %%
arr = np.array([0,1,2,0,2,3,0])
print(list(np.nonzero(arr)))
# Out:
# [array([1, 2, 4, 5])]

# %%
arr = np.random.randint(10,100,9).reshape(3,3)
print(arr)
# Out:
# [[67 16 43]
#  [52 32 69]
#  [59 70 82]]

# %%
np.clip(arr,30,75)
# Out:
# array([[67, 30, 43],
#        [52, 32, 69],
#        [59, 70, 75]])

# %%
arr = np.array([1,2,np.nan,4,5])
arr[np.isnan(arr)] = 3
arr
# Out:
# array([1., 2., 3., 4., 5.])

# %%
np.random.seed(42)
arr = np.random.randint(10,100,9).reshape(3,3)
arr
# Out:
# array([[61, 24, 81],
#        [70, 30, 92],
#        [96, 84, 84]])

# %%
np.sum(arr,axis=0)
# Out:
# array([227, 138, 257])

# %%
np.sum(arr,axis=1)
# Out:
# array([166, 192, 264])

# %%
np.mean(arr,axis=0)
# Out:
# array([75.66666667, 46.        , 85.66666667])

# %%
np.diagonal(arr,offset=2)
# Out:
# array([81])

# %%
np.trace(arr)
# Out:
# np.int64(175)

# %%
np.diag([10,20,30,40])
# Out:
# array([[10,  0,  0,  0],
#        [ 0, 20,  0,  0],
#        [ 0,  0, 30,  0],
#        [ 0,  0,  0, 40]])
