# %%
A = 1,2,3,4,5,5,"adadasdasd","Q1",1.1,True
print(type(A))
print(A)

# numpy arrey(Numarical python)
"""
dynamic and vactrise(matlab ek sath) 
limitation: cannot suppot more than 1 data type
"""
###
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5, 5, 'adadasdasd', 'Q1', 1.1, True)
# '\ndynamic and vactrise(matlab ek sath) \nlimitation: cannot suppot more than 1 data type\n'
