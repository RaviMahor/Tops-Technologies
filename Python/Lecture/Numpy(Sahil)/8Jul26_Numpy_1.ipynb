# %%
"""
Ran command: `pip3 install numpy
`
Ran command: `python3 -m pip install numpy`

इन दोनों कमांड्स में `3` और `-m` का बहुत ही महत्वपूर्ण मतलब है। आइए इन्हें आसान शब्दों में समझते हैं:

---

### 1. `pip3` में `3` क्या है?
`3` का मतलब **Python Version 3** है।

* **इतिहास:** पहले कंप्यूटरों में Python 2 और Python 3 दोनों इंस्टॉल हुआ करते थे।
  * Python 2 के पैकेजेस इंस्टॉल करने के लिए `pip` कमांड का इस्तेमाल होता था।
  * Python 3 के पैकेजेस इंस्टॉल करने के लिए `pip3` कमांड का इस्तेमाल होता था।
* **काम:** यहाँ `pip3` यह पक्का करता है कि जो भी पैकेज (जैसे `numpy`) आप इंस्टॉल कर रहे हैं, वह आपके कंप्यूटर में मौजूद **Python 3** के लिए ही इंस्टॉल हो।

---

### 2. `python3 -m pip` में `-m` क्या है?
`-m` का फुल फॉर्म है **"Module"** (मॉड्यूल)।

जब आप `python3 -m pip ...` लिखते हैं, तो आप कंप्यूटर को सीधे यह निर्देश दे रहे होते हैं:
> *"पायथन 3 (python3) को चलाओ और उसके अंदर मौजूद `pip` नाम के **मॉड्यूल** (`-m`) को लोड करके पैकेज इंस्टॉल करो।"*

#### इसका फायदा क्या है?
कभी-कभी आपके कंप्यूटर में `pip3` कमांड सीधे काम नहीं करता (जैसे "command not found" एरर आ जाना)। लेकिन `python3 -m pip` हमेशा काम करता है क्योंकि यह सीधे Python के मुख्य सॉफ़्टवेयर का इस्तेमाल करके उसके अंदर के `pip` को एक्टिवेट करता है। यह सबसे सुरक्षित और सही तरीका माना जाता है।
"""
# Out:
# '\nRan command: `pip3 install numpy\n`\nRan command: `python3 -m pip install numpy`\n\nइन दोनों कमांड्स में `3` और `-m` का बहुत ही महत्वपूर्ण मतलब है। आइए इन्हें आसान शब्दों में समझते हैं:\n\n---\n\n### 1. `pip3` में `3` क्या है?\n`3` का मतलब **Python Version 3** है।\n\n* **इतिहास:** पहले कंप्यूटरों में Python 2 और Python 3 दोनों इंस्टॉल हुआ करते थे।\n  * Python 2 के पैकेजेस इंस्टॉल करने के लिए `pip` कमांड का इस्तेमाल होता था।\n  * Python 3 के पैकेजेस इंस्टॉल करने के लिए `pip3` कमांड का इस्तेमाल होता था।\n* **काम:** यहाँ `pip3` यह पक्का करता है कि जो भी पैकेज (जैसे `numpy`) आप इंस्टॉल कर रहे हैं, वह आपके कंप्यूटर में मौजूद **Python 3** के लिए ही इंस्टॉल हो।\n\n---\n\n### 2. `python3 -m pip` में `-m` क्या है?\n`-m` का फुल फॉर्म है **"Module"** (मॉड्यूल)।\n\nजब आप `python3 -m pip ...` लिखते हैं, तो आप कंप्यूटर को सीधे यह निर्देश दे रहे होते हैं:\n> *"पायथन 3 (python3) को चलाओ और उसके अंदर मौजूद `pip` नाम के **मॉड्यूल** (`-m`) को लोड करके पैकेज इंस्टॉल करो।"*\n\n#### इसका फायदा क्या है?
# ...

# %%
import numpy as np
print("NumPy version:", np.__version__)
# Out:
# NumPy version: 2.0.2

# %%
import numpy as np
# Creating a 1D Numpy array
b = [10,20,30,40]
print(b)
arr = np.array([10,20,30,40])
print("Numpy Array:", arr)
print("Type:", type(arr))
# Out:
# [10, 20, 30, 40]
# Numpy Array: [10 20 30 40]
# Type: <class 'numpy.ndarray'>

# %%
#Python list
list_data = [1,2,3,4]

# Numpy array
array_data = np.array([1,2,3,4])

print("List:", list_data)
print("Array:", array_data)
# Out:
# List: [1, 2, 3, 4]
# Array: [1 2 3 4]

# %%
# List operation (requires loop)

result_list = []
for i in list_data:
    result_list.append(i + 5)
print("Update List:", result_list)

# Numpy operation (vectorized)
print("Updated Array:",array_data + 5)
# Out:
# Update List: [6, 7, 8, 9]
# Updated Array: [6 7 8 9]

# %%
# 2D Array (Matrix)

matrix = np.array([[1, True, 3],
                   [4,5,6]])
A = [[1,2,3],[4,5,6]]                   
print(A)
print("2D Array:")
print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6]]
# 2D Array:
# [[1 1 3]
#  [4 5 6]]

# %%
print("Shape:", matrix.shape)
print("Number of dimensions:", matrix.ndim)
print("Total elements:", matrix.size)
print("Data type:", matrix.dtype)
###
# Out:
# Shape: (2, 3)
# Number of dimensions: 2
# Total elements: 6
# Data type: int64
