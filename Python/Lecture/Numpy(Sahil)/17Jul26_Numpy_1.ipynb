# %%
"""any all"""

# %%
import numpy as np

a = np.array([5])
b = np.array([0])

print(a / b)  
# Output: [inf] (Saath mein ek warning aayegi, lekin code crash nahi hoga)
# Out:
# [inf]
# /var/folders/xg/66ph2dms1f1cgr6nlsjrfjv80000gn/T/ipykernel_15766/3312755271.py:6: RuntimeWarning: divide by zero encountered in divide
#   print(a / b)

# %%
print(np.log(0))  
# Output: -inf (Negative Infinity)
# Out:
# -inf
# /var/folders/xg/66ph2dms1f1cgr6nlsjrfjv80000gn/T/ipykernel_15766/2963665399.py:1: RuntimeWarning: divide by zero encountered in log
#   print(np.log(0))

# %%
print(np.inf + 1000)  # Output: inf
print(np.inf * 2)     # Output: inf
# Out:
# inf
# inf

# %%
print(999999999 < np.inf)  # Output: True (Kyunki infinity sabse badi hai)
# Out:
# True

# %%
print(np.inf - np.inf)  # Output: nan (Kyunki infinity - infinity defined nahi hai)
# Out:
# nan
