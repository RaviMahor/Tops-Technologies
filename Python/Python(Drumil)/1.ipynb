# %%
# program - python - IDE - anti gravity 

print("hello")
print(4)
print(5+5)


# print - function in build print 

# function vs method 

# class code - def - method //oops based 
# without class - function
# Out:
# hello
# 4
# 10

# %%
a="hello"
b=4 # value assign =   # == 
c=5.8
d=True
e=False

print(type(a))
print(type(b))# variable 
print(type(c))
print(type(d))
print(type(e)) # class based //oops // functional way
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %%
x=int(input("enter first numne")) #5
y=int(input("enter second number")) # user inpput # 5

#  default datatype string 
# "5" +"5"=concat = 55
# styring = int = datatype convert = type casting 
print(x+y) #10 concat
# Out:
# 10

# %%
x1=int(input("enter first numne"))

if x1 > 40:
    print("all ok")
else:
    print("not ok")    # condistion true = if 
                       # else

# %%
x2=int(input("enter first numne"))

if x2 > 90:
    print("ok")
elif x2>70:
    print("all ok")
elif x2 >50:
    print("okkkk")
else:
    print("not ok")    


#  == 
    # 1 cond - true - if 
    # 2 true and false = if else
    # multiple condistion  if elif else     
    #  username - tops 
    #  password -123 login suuc   // login failed

# %%
# == = value check and === value and data type both 
# 
#  error vs exception 
# what is error ? syntax 2 logic = id 
# dfg
#sdfsdf
#dfgdg
#dfgfg output 
#dddd // exception - never solve - handle 
#sff
#sdfs
#fggffg   error  solve 

# abnormal condistion which hamper normal condistion 
# 6 to 7 =6.48 light stop solution 
# most of case exception - third party 
# python - sql - run //mysql - db internall issue handle 
#third party 

# try except finally
