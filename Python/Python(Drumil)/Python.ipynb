# %% [markdown]
# python - programing lang //code
# python is partial oops
#
#
#  python high level programing lang
#        human - as simple way code //english 010101
#  python is interprated lang
#
#   // c = code - run - convert machine lang 01010101/binary
#
# // code - run -byte code -convert - machine code 0101010
# // python platform dependent
# //python code platform independent
#         platform independent
# // python =pre run time enviroment // python prog run enviroment
#              pvm - python virtual machine
#
#                 code load - execute -verity
#            os
#  1 types of lang
#
#      - procedure -c lang
#
#         code - run - top to bottom =
#
#       -oops - java,python ,php
#   /logic/code
#           1 fully object
#       - oops all concept use
# class object inheritance encapsulation
# polymorphism abstraction
#
#   python - in build - as a object
#           2 partial object - only oops concept use
#       - marqup -  tag -1 html- hyper text marqup lang 2 xml
#                  extensible marqup lang
#
#       - modeling - uml - unified modeling lang
#
#                     diagram flow chart
#
#            1 python mainly use
#
#                     1 data science
#                      2 data analytics
#                      3 web development //java node php
#                      4 automation testing - java,js
#                      5 web scraping
#  --------------------------------------------------------
#
#                        what is variable, data types , function
#          one kind of container which store the value
#                         a=55,
#                         b=6,
#                         c=7 = a a time single value store
#
#                        data types
#                            b="6.9"// which data store
#                             c="hello"- group of word - sentance
#                            # int float string boolean
#
#        true and false - primitive data types - python in build never customization
#                             d=True
#                             e=False
#
#
#           non primitve - multipe data store with diff diff data types
#
#                       - user defined
#                          list tuple set dict
#                           //data store -container
#                           # object
#                            x=[10,20,True,"hello",7.8,90,False] //list
#                            y=10
#                            z="hello"
#                   print(y)=10
#                   print(type(x))= class - list
#                           data types type
#
# --------------------------------------------------------------------
#
#      what  is function
#
#                collection of code that code we will use for particular task
#
#                  python 2 types
#                          1 in build func
#                          2 user define
#                          3 keyword - def
#                          4 syntax
#
#                           def login(): without parameter
#
#                          def login(a, b):with parameter
#   //multiple code
#
#                               login()
#                               login(20,30)// argument
#                     output - function call - function name

# %%
x1 = int(input("Enter here your number"))
if x1 > 40:
    print("all ok")
else:
    print("not ok")
# Out:
# all ok

# %%
x2 = int(input("Enter here your number"))
if x2 > 40:
    print("all ok")
elif x2 > 70:
    print("okey")
elif x2 > 90:
    print("great")
else:
    print("not ok")
# Out:
# not ok

# %% [markdown]
# 1 cond - true - if
# 2 true and false = if else
#   multiple condition --     if elif else
#
# # username - login
# # password - 123 login suuc // login failed

# %%
login = str(input("Enter your login id in text"))
password = int(input("Enter your password in number"))

if password == 1234:
    print(f"your login id is: {login}")
    print(f"login successfull")
else:
    print(f"your login id is: {login}")
    print(f"Entered Wrong password 'try again later'")
# Out:
# your login id is: giii
# Entered Wrong password 'try again later'

# %% [markdown]
# # interview que
# = or == between diffrence?

# %% [markdown]
# error vs exception
# what is error ? syntax 2 logic = id
# code:
# dsfs
# sfsf
# ss
# ss
# sdfs -- output
# sdsf// exception - never solve - handle
# weweqe
# qerq    // error solve
#
# exception : abnormal condition which hamper normal condition
# most of case exception -- third party
# python - sql - run // mysql - db internall issue handle
#
# python have 3 type of exception hadle methods
# try - except - finally

# %% [markdown]
# try -- code
# except -- handle exception
# finally -- always execute -- optional
#
# 2 scenerio execute
#
# code -- exception handle
# third party integration -- api -- third party
#
#
#
# opps things ------------ interview first question
#
# --class            -- collaction of function,variable, datatypes,constructor, object, (destructor,quition mark)
# class login:
#     def test():
#         a=2
# x = login()         -- x = login() -- object -- login() = constructor (-- initialize,quition mark)
# a = 6 -- variable
# x.test()
#
# p = [10,10.1, "hello", True] -- list - non primitve data type // primitive data type -- int, float, string, boolean
# print(p) -- auto boxing and unboxing -- primitive data type convert to non primitive data type
#
#
#
# class can call multiple time
# like x = login()
#     x1 = login() ------------- class call with object
#
# class not ocuping memory (-- only when object create -- memory allocate,quition mark)
#
# class name - constructor (- __init__() -- initialize object -- constructor,quition mark)
# class - python comp - default constructor create (-- user define constructor -- __init__() -- initialize object,quition mark)
# constructor -- actual work method
# method -- call -- return
# constructor -- never call - automatic -- no return
# y = [] -- initialize list
# z = {} -- initialize dictionary
#
#
# ------interview quition--------------  what is deffrence between method or constructor?
#
#
# class create = code = execute = initialize (= constructor,quition mark)
#
# --object           --
# --inheritance
# child class can use the fun of parent class
# min - 2 class
# 1-parent class
# 2-child class
# class parent():
#     def login():
#         pass # 100 lines of code
# class child(parent):
#     def test():
#         pass
#
#         # 100 lines --- duplicate code -- heavy weighted -- load
#         # code reuse
#         -- code optimization -- output -- code
#         # 1 single 2 multiple 3 multi level 4 hirarchical 5 hybrid
#         # child class 1 - parent class multiple
#
#         2 multiple
# class parent():
#     def login():
#         pass # 100 lines of code
# class Test():
#     def reg():
#         pass # 100 lines of code
# class child(parent,Test):
#     def test():
#         pass
#
#         3 multi level
#  class parent():
#     def login():
#         pass # 100 lines of code
# class Test(parent):
#     def reg():
#         pass # 100 lines of code
# class child(Test):
#     def test():
#         pass
#
#         5 hybrid
#  class parent():
#     def login():
#         pass # 100 lines of code
# class Test(parent):
#     def reg():
#         pass # 100 lines of code
# class child(Test,parent):
#     def test():
#         pass
# class four(child):
#     pass
#
#         4 hirarchical
#  class parent(Test):
#     def login():
#         pass # 100 lines of code
# class Test():
#     def reg():
#         pass # 100 lines of code
# class child(Test):
#     def test():
#         pass
# class four(Test):
#     pass
#
# ------interview quition-------------- what is polymorphism? and what is method overloading and method overriding?
# --polymorphism -- one name multiple form
# idris - tops - student
# idris - job - employee
# method overloading -- same method name with different parameter
# 1 no of argument 2 data type (of argument 3 sequence of argument)-- quition mark
# class tops():
#     def test(a):
#         print("hello")
#     def test(a,b):
#         print("hello")
# method overriding -- same method name with same parameter
#
# --abstruction -- hiding the implementation details -- ABC
#
# --encapsulation -- data wrapping -- private variable (-- getter setter method -- access private variable,question mark)
#
# example of data wriapping
# class test():
#     def test():
#         print("hello")

# %% [markdown]
# interview que--------------- what is diffrence between function vs method
#
#
# types of function
# -- inbuld
# -- user define
#
# 1. no paramente no retun
# 2. parameter no return
# 3. no parameter return
# 4. parameter return
#
#
# -- def = function declare login -- fun name () parameter :- function body
# def login():
#     print('hello python')
#
#     login() -- function calling
#
# def login1(name):
#     print(name)
#
# login1("rahul")
# ----------------------------- declaretion and excution at same time same place
# def login2(a,b):
#     print(a+b)
#
#     login(5,50)
#
# def login3(c,d):
#     return c+d
#
#     login3(5,6)
#
# ----------------------------- declaration and execution futute ............exp----- data=login(2,3) stored in data when needed call it in future
#
# -- print = third never use
# -- return = usefull for store variable -- chaining 1-2-3-4-....
#
#
#
#
# hw... user input = function
#         parameter and return
#
#         2 number input = multiplication

# %% [markdown]
# --- non primitive data type
# - at a time multiple data store with diff diff data types
# -- list, tuple, set, dict
#
# 1. list - data structure - algorithm - dynamic array
#
# // array vs dynamic array
#
# # 1 - string
# ---- run time never 50 // exception array - fixed size - memory allocate - run time never change

# %% [markdown]
# # function  variable datatypes
#
# # collection of code that code we will use for particular task
# # reuseble
# # fun vs method - class - inside - method
# # call fun name  // class object
# # class test():
# #   def xyz():
# #x=test()
# # x.xyz()
#
# # types function declare python  - in build 2 user defined
#
# # 1 no parameter no return
# # 2 parameter no return
# # 3 no parameter return
# # 4 parameter return
# # def =  fun declare login - fun name () parameter :- function body
# # fun data
# def login():
#     print("hello python")
#
#     login() # function calling
#
# def login1(name):
#     print(name)
#
#     login1("rahul")
#
# # declration and execution at a same time same place
#
# def login2(a,b):
#     print(a+b) #55
#
#     login(5,50)
#
# def login3(c,d):
#     return c+d
#
# data=login3(5,6)
#
# print(data)
#
#
# def login4(name="dhrumil"):
#     print(name)
#
#     login4()
#     login4("rahul")
#
# def login5(rollno,age):
#     print(rollno,age)
#
#
#     login5(age=20,rollno=123)
#
#      # age name
#      # declaration  and execution future
# # print = third never use  variblr = store
# # return    chaining 1-2-3-4  act fun
#
# # user input = function
# # parameter and return
#
# # 2 number input  = multiplication 30

# %% [markdown]
# # non primitve data type
#
# #  at a time multiple data store with diff diff data types
#
# # list , tuple , set , dictionary
#
# # 1 list -  data structure - algortiham - dynamic array
#
# #  array vs dynamic array
#
# # 1 - string
# # run time never 50 // exception arra - fix size
# #

# %%
"""
hw... user input = function
        parameter and return

        2 number input = multiplication
"""
user_input1 = int(input("Enter first number: "))
user_input2 = int(input("Enter second number: "))

def multiply_numbers(num1, num2):
    return num1 * num2

result = multiply_numbers(user_input1, user_input2)
print("The product is:", result)
# Out:
# The product is: 4

# %% [markdown]
# # function (parameter): - return value
# # array vs dynamic array # run time value add
# # list - ds - algorthiham = dynamic array
#
# # index based access // index
#
# # access - random access
# # search operatuon // insert.update delete (- linear search 1 - binary search 1,2,3,4....,quistion mark)
# # first element = 0 index
# # value - change - mutable - list
# # list - duplicate value allow/store

# %%
x = [10,20,30,40]
print(x[4])  # This will raise an IndexError since index 4 is out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 x = [10,20,30,40]
# ----> 2 print(x[4])
#
# IndexError: list index out of range

# %%
x = [10,20,30,40] # list multiple value store
print(x)

# %%
x = [10,20,30,40,"ds","da"] # list multiple value store
print(x)

# %% [markdown]
# -- what is index shifting

# %% [markdown]
# -- api -- indipendent language -- python,java,php,js,go,ruby
# -- which api -- dependent language -- c,c++,c#,assembly,fortran,perl

# %%
x=[10,20,30,40,"ds","da"] # list multiple value store

x.remove(20) # remove value from list
print(x)
# Out:
# [10, 30, 40, 'ds', 'da']

# %%
x=[10,20,30,40,"ds","da"] # list multiple value store

x.pop(2) # remove value from list
print(x)

# %%
"""function list me min max avg len kya hea? function ----------- interview"""
x=[10,20,30,40,"ds","da"] # list multiple value store
print(max(x))
print

# %% [markdown]
# type castiong----------------
# autoboxing and unboxing -------------------- interview quistion
#
#
# loop = non primitive  - foreach loop
# for loop         int- primitive
# for(i=0;i<10)
#
# meaning od iteat or itreation

# %%
list1 = ["da","ds"]
user_name = int(input("enter name"))
# for i in list1():

    if i == user_name:
        print(f"value matched {i} with user_name")
    else:
        print("value not matched with data")
# Out:
#   Cell In[12], line 5
#     if i == user_name:
#     ^
# IndentationError: unexpected indent

# %%
x = [50,10,20,20,30]
print(x.sort())
# Out:
# None

# %%
"""diff between append and extend----------interview que"""

# %%
# api - application programming interface
# PYTHON / BACKED LANG //API


# FAST API TYPE OF API CREATION
# ADVANTAGES
# 1 - LANG INDEPENDENT
# 2 - API SECURE - USAGE OF THING / ORIGNAL CODE NOT ACCECABLE


# cliant side          API          server side

# da/ds -   USE - API key - USE = Access

# GEMENI // API KEY

# DATA - TABLE 
# API - 2 TYPES

# 1 REST API - NO PROTOCOL FOLLOW - LOW BANDWITH CALL
 # JSON(JAVA SCRIPT OBJECT NOTATION),XML(EXTENSIBLE MARQUP LANGUAGE),HTML,XHTML,TEXT
 # DICT - KEY AND VALUE
 # TAG <NAME> RAHUL </NAME>
 # LESS SECURE
# 2 SOAP API - PROTOCOL FOLLOW - HIGH BANDWITH CALL
# XML = HIGH SECURE
# SECURITY - SOAP 

# METHOD
# POST - DATA INSERT - 201
# PUT - UPDATE - ALL NAME ADD CITY - 200
# PATCH - ONLY ONE UPDATE
# GET - SELECT - 200 
# DELETE - 200
# CHECK - VALID PROPER // POSTMAN PYTHON // FRONT END INTEGRATION

# MODEL/AI - API

"""WHAT IS DIFFRENCE BETWEEN PUT VS PATCH"""

"""
code - pass - get
post =

cross platform

python - api - backend - window
frontend - cross platform
mobile app - android ios * = allow
.*-api

local machine code - build file - single file convert

1 function
2 function
app - code - apk - build

local code - github repo push - github action - test -build - server integration

deployment / Simple
+ Extra CI/CD 

# cont integration and cont deployment

#Github action - own infrastructure use
#jenkins - own infrastructure 

 """

# task - HW
# HTML css - 1 web page - local - github push - server dep - 
# netify / versal

# %%
"""
tuple 
next datatype tuple

non primiive
order
duplicate value allow
index - access
immutabel - modify never
data structure - array based

example of list
x = [10,20]
x[1]=50
print(x) - modified

x.append()
x.insert()
x.extend()

interview quition --- what is diff between list and tuple

multiple method a = tuple 1 count 2 index
"""
# Out:
# '\ntuple \nnext datatype tuple\n\nnon primiive\norder\nduplicate value allow\nindex - access\nimmutabel - modify never\ndata structure - array based\n\nexample of list\nx = [10,20]\nx[1]=50\nprint(x) - modified\n\nx.append()\nx.insert()\nx.extend()\n\ninterview quition --- what is diff between list and tuple\n\nmultiple method a = tuple 1 count 2 index\n'

# %%
x = (10,20,30)

print(x)

print(type(x))

# tuple =. project = data = manuplation python
# immutable = tuple store // problem

# %%
y = 10,20,30 # variable = tuple 
print(y)
print(type(y))
# () is not a tuple, Tuple is ,

# %%
z = (10)
print(z)
print(type(z))
a = (1,)
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>
# (1,)
# <class 'tuple'>

# %%
z = (10,20,30,40)

z[2] = 50 # coz tuple is immutable



print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 z = (10,20,30,40)
# ----> 3 z[2] = 50
#       5 print(z)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# what is tuple modification or tuple concinate

# %%
z = ([10,20],90)

print(type(z))
print(z)
print(z[0])

z[0].append(90)
print(z)

# %%
z1 = (10,20,30)

del z1[0]
print(z1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 z1 = (10,20,30)
# ----> 3 del z1[0]
#       4 print(z1)
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
z1 = (10,20,30)

del z1
print(z1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 z1 = (10,20,30)
#       3 del z1
# ----> 4 print(z1)
#
# NameError: name 'z1' is not defined

# %%
z1 = (10,20,30)

z1.count(10)
print(z1)
z1.index(20)
print(z1)
# Out:
# (10, 20, 30)
# (10, 20, 30)

# %%
# packing of tuple
x = 10,20,30,40
print(x)
print(type(x))

# unpacking of tuple
x = 10,20,30,40
print(x)
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>
# (10, 20, 30, 40)

# %%
x1,x2,x3,x4 = x
print(x1)
print(x2)
print(x3)
print(x4)

""" what is packing and unpacking of tuple"""
""" what is autoboxing and unboxing"""
""" what is diffrence between unpacking ans unboxing"""

x1 = ("ds",25,"mumbai")

course,age,city = x1
print(course)
print(type(course))
print(age)
print(type(age))
print(city)
print(type(city)) # unpacking // unboxing
# Out:
# 10
# 20
# 30
# 40

# %%
# set = data structure = algorithm = hash table = hash function = hash value = hash index = hash collision
# set = unorder collection of data
# set = no index
# set = no duplicate value
# set = no order
# set = no index
# set = no duplicate value


# interview que = what is hashing technique

# list tuple = value based access
# set = key value based access

# set = no index
# set = no duplicate value
# set = no order
# set = hashcode
# set = hash function
# set = hash value
# set = hash index
# set = hash collision
# set = hash table

""" what is hash table"""
"""
set never allow duplicate value
"""

# %%
"""
what diffrence between list and set
"""
x ={10,20,30,40,50}
print

# %%
"""what is type casting"""
""" what is diffrence between add and append"""
""" what is diffrence between remove and discard"""

# %%
""" what is micro service"""
"""
api =
zomato - app - user

role 1 - customer - 10 api
role 2 - admin - 20 api
role 3 - delivery partner - 10 api
role 4 - restaurant owner - 10 api

system design - ai ai ai 

monolithic architecture - 10000 line of code - api 

micro service architecture - 1000 line of code - api 



























"""
