# %%
# try - code 
# except 
# finally-optional 

# python - sql 
#memory - heavy weight - load /slow //memory leak 
# connection create 
#connection open 

#connection close 
# 1 finally - use 
# 2 scenario execute 
# transction open - close 
def datainsert():
    pass  # 1 insert close 
# code - exception 
#third party integration 
# sql mongodb // db 
# payment gateway paypa pay stripe 
# 
##################################################

# class 

# collection function/method, variable, datatypes,
# constructor and object 
#encapsulation = data wraping // 

class test():

    def test():
      print("helo")

x=test()
x.test()






class login():

    def test():
        a=2
x=login() #object  
a=6  #var
x.test()  #iniaization  x= object login=constructor

p=[10,7.9,"hello"]  # list -non primi   // primit
print(p)# auto boxing and unbpxing 
#x1=login()
#a=1 class object 
# class name - constructor 
#class - python comp - default const create 
# constu - actual work method 
# method - call return 
#const - never call -automatic 
y=[]#inialization class 
z={}  
# class create = code =execute = inilization 
#         
#object
# inheritance 

# child class can use the fun of parent class 

# min - 2 class 
# 1 - parent
# 2 - child 
class parent(test):
    def login():
        pass # 100 line
class test():
    def reg():
      pass
class child(test): # only 1 class access 
    pass

class four(test):
    pass

#print("hello") print(4)
# polymorphism- one interace and multiple implementation 
#  idris -   tops - student 
#  idris - job - emp  
#  method overloading
# method overiding - python always last call - inheritance - this and super self 
#  method overloading - 1 class - more than 1 method - method name same 
 # -method parameter diff same 
# 1 no f argument 2 data type 
class tops():

    #def student(name,mobileno):
      #  pass

    #def student(address,rollno):
        #pass

    # concat()
    def student(name,mobileno,address,rollno):
        pass

    student("rahul",8866)
    student("ahmd","123")
    #100 line  duplicate code = heavy weighted = load 
 # 
    # code reuse 
    #code optimization  # output = code =
    # types of inheritance
    # 1 single 2 multiple 3 multilevel 4 hybrid 5 heirarchical
    # child class 1 - parent class multiple   
    # chain 
    # single more than 1 inheritance use 
    #heirarchical - parent 1 child multiple 
#polymorphism 
#abstraction - sensitive data class abstract class ABC abstract method 
#encapsulation
