# %%
# function(parameter ): 

#array vs dynamic array #run time value add 

#pre defined size 

# list - ds - algortiham - dynamic array 

# index based access // index 

# access - random access 
# search operation  // insert.update delete 
# first element = 0 index 
#  value - change -mutable - index 
#list - duplicate value store

# %%
x=[10,20,30,40] # list multiple value store 
print(x)
# Out:
# [10, 20, 30, 40]

# %%
x=[10,20,30,40,"ds","da"] # list multiple value store with diff diff datatypes  
print(x)
# Out:
# [10, 20, 30, 40, 'ds', 'da']

# %%
x=[10,20,30,40] # list multiple value store 
print(x[0])
print(x[1])
print(x[2]) # data access index 
print(x[3])
# Out:
# 10
# 20
# 30
# 40

# %%
x=[10,20,30,40] # list multiple value store 

print(x[2]) # random access
# Out:
# 30

# %%
x=[10,20,30,40] # list multiple value store 

print(x[4]) # list index = access
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 x=[10,20,30,40] # list multiple value store
# ----> 3 print(x[4])
#
# IndexError: list index out of range

# %%
x=[10,20,30,40] # list multiple value store 

print(x)

x[2]=80 # list mutable 

print(x)
# Out:
# [10, 20, 30, 40]
# [10, 20, 80, 40]

# %%
x=[10,20,30,40] # list multiple value store 

print(x[-1])
print(x[-4])
print(x[0])
print(x[3]) # positive and negative index data access 

# -1  -4 = -1 =0 
# 1  4  = 4
# Out:
# 40
# 10
# 10
# 40

# %%
x=[10,20,30,40] # list multiple value store 

x.append(90) # list = method  function 

print(x) # add - append
# Out:
# [10, 20, 30, 40, 90]

# %%
x=[10,20,30,40] # list multiple value store 

x.append(80,60) # list at a time single value add 

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 x=[10,20,30,40] # list multiple value store
# ----> 3 x.append(80,60)
#       5 print(x)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
x=[]

x.append("DA")
x.append("ds")
x.append("ml")

print(x)
# Out:
# ['DA', 'ds', 'ml']

# %%
x=[10,20,30,40] # list multiple value store 

# 1 element add 
x.insert(2,60) # index shifting index = tv

print(x) # index shift  structure well  maintan //

# search //  json = dict = key and value
# Out:
# [10, 20, 60, 30, 40]

# %%
#mysql = table row and column 
# columns - api - key 
# data store //platform // 

# scraping -  orm / odm 
#xyz -api - json =  store table  
# json 

#client side-username/pass - store-json key and value  api-rest - json                                       database (server side)

# %%
x=[10,20,30,40]
 
print(x)

#  user name  -ds name matched ai=not matched   list=["ds","da"]
x.remove(20) #value based
#index shift //list delete perfrom 
# delete function = list use search 
# after shifting  5lakh cr // slow 
print(x[1])

print(x)
# Out:
# [10, 20, 30, 40]
# 30
# [10, 30, 40]

# %%
x=[10,20,30,40]
print(x)

x.pop(2) #index based shifting 

print(x[2])
print(x)

#
# Out:
# [10, 20, 30, 40]
# 40
# [10, 20, 40]

# %%
x=[10,20,30,40]

print(len(x)) #1 //0 
print(sum(x))
print(min(x))
print(max(x))  # function // list object //
# Out:
# 4
# 100
# 10
# 40

# %%
x=[10,20,30,40] #non primi int primitve to non primit 

print(x) # list method 
#print(type(x))  #autoboxing and unboxing 
 
for x1 in x:   # //non primit = primitve without type casting 
    print(x1)
   # print(type(x1))


    # loop =  non primitive - foreach loop 
    # for loop  int- pri
    # for(i=0;i<=10;i++) inializ condistion increment or dec
# Out:
# [10, 20, 30, 40]
# 10
# 20
# 30
# 40

# %%
x=[10,20,30,40] #non primi int primitve to non primit 

y=input("ent u rno")

if y in x:
    print("sd")
else:
    print("add")

# %%
x=[10,20,30,40]

x.reverse()

print(x)
# Out:
# [40, 30, 20, 10]

# %%
x=[50,10,30,20,40]

x.sort()

print(x)
# Out:
# [10, 20, 30, 40, 50]

# %%
x=[10,20,30,40]

x.append([70,90]) #numeric 

print(x)

print(x[4]) # 1 index
# Out:
# [10, 20, 30, 40, [70, 90]]
# [70, 90]

# %%
x=[10,20,30,40]

x.extend([70,90]) #list 

print(x)
print(x[4])
# Out:
# [10, 20, 30, 40, 70, 90]
# 70

# %%
# Api -application programing interFACE 
#PYTHON / BACKEND LANG //API 
#USE
#ADVANTAGES
 #fasT API,FLASK  , J
 #
 # 1 - LANG INDEPENDENT 
 # 2- API SECURE 
 #
#CLIENT SIDE            API                        SERVER SIDE 

# da/ds = USE- API KEY = USE = ACCESS 
# UBER = MAP USE 
# GEMINI // API KEY 

# DATA  - TABLE 
# API -  2 TYPES 

# 1 REST API= NO PROTOCOL FOLLOW , LOW BANDWIDTH CALL
 # JSON- JAVA SCRIPT OBJECT NOTATION, XML- EXTENSIBLE MARQUP LANG , HTML,XHTML, TEXT
 #  DICT - KEY AND VALUE 
 # TAG <NAME>RAHUL</NAME>
 # LESS SECURE 
# 2 SOAP API - PROTOCOL FOLLOW , HIGH BANDWIDTH 
# XML = HGH SECURE
# SECURITY - SOAP 
#NAME ADD CITY 
# METHOD
#POST- DATA INSERT 
#PUT-UPDATE 
#PATCH -
#GET-SELE
#DELETE - FRONT END -AI - WEBSITE /APP 
# CHECK - VALID PROPER //POSTMAN  PYTHON FRONT END INTEGRATION 
#MODEL/AI - API 
# https://681444af225ff1af16285b31.mockapi.io/electronicapi
#=================================================
# code -pass -get  
# post =

#cross platform 

#python -api - backend -window 
#frontend - cross platform 
#mobile app -andorid ios * =allow 
#.*-api 

# local machine code - build file -single file convert 

# 1function 
#2 function 
#app - code -apk -build 
# 1 
# local code - github repo push -github action- test -build  -  server integration 
#deployment /simple 
# server
# extra ci/cd 
#  3000- prive3to 4 
# cont integration and cont deployment 
# 
# github action - own infrastructure use 

#jenkins- own infsta 
#=================================

#html css js- chat/ own  - 1 web page -local - github push - server dep 

# deploy tuple

# %%
gemini-agent
│
├── src/main/java
│   └── com.example.geminiagent
│       │
│       ├── GeminiAgentApplication.java
│       │
│       ├── controller
│       │   └── AgentController.java
│       │
│       ├── service
│       │   └── ProductService.java
│       │
│       ├── model
│       │   └── Product.java
│       │
│       ├── tool
│       │   └── ProductTools.java
│       │
│       └── agent
│           └── ProductAgent.java
│
├── src/main/resources
│   └── application.properties
│
└── pom.xml
