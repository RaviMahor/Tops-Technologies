# %%
# https://youtu.be/EFmxPMdBqmU?si=1o8BOzUdKbCOkU4A&t=164

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.bar(range(len(val)),val)
while True: 
    val = np.random.randint(1,10,100)
    plt.show()
